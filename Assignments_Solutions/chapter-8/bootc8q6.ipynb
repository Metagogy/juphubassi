# %% [markdown]
# **Question**: Load, Split, normalize and flatten the mnist dataset. Build, compile, train and evaluate the model using adam optimizer, loss as "categorical_crossentropy".

# %% [markdown]
# **Description :**
#
# Load the mnist dataset using inbuilt dataset function and split into training and testing images.
#
# Normalize the dataset images by dividing it with 255 and subtract 0.5 of train and test images.
#
# Flatten the dataset images by using reshape.
#
# Build the mnist dataset model by using a sequential layer and adding first two activation functions as Relu layers having 64 neurons in each dense layer and last layer having activation function as Softmax layer with 10 neurons.
#
# Compile the model using adam optimizer, loss as "categorical_crossentropy" and train the model using 5 epochs, 32 as batch size.
#
# Evaluate the mnist model by using test images and labels.

# %% [markdown]
# **Level :** Hard

# %% [markdown]
# **Input format :**
#
# Dataset

# %% [markdown]
# **Output format :**
#
# Model Accuracy

# %% [markdown]
# **Sample input :**
#
# Load the dataset using inbuilt function

# %% [markdown]
# **Sample Output  :**
#
# Accuracy : 0.80

# %%
import tensorflow as tf
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

# Normalize the images.
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

# Flatten the images.
train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

# And to the following:
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(64, activation = 'relu' , input_shape=(784, )))
model.add(tf.keras.layers.Dense(64, activation = 'relu' ))
model.add(tf.keras.layers.Dense(10, activation = 'softmax' ))
model.summary()

# Compile the model.
model.compile('adam', loss=tf.keras.losses.CategoricalCrossentropy() ,  metrics = ['accuracy'] )

# Train the model.
model.fit(
  train_images,
  tf.keras.utils.to_categorical(train_labels),
  epochs=5,
  batch_size=32,
)

# Evaluate the model.
model.evaluate(
  test_images,
  tf.keras.utils.to_categorical(test_labels)
)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 14s 236us/sample - loss: 0.3600 - accuracy: 0.8931
# Epoch 2/5
# 60000/60000 [==============================] - 13s 212us/sample - loss: 0.1893 - accuracy: 0.9436
# Epoch 3/5
# 60000/60000 [==============================] - 14s 235us/sample - loss: 0.1456 - accuracy: 0.9552
# Epoch 4/5
# 60000/60000 [==============================] - 14s 239us/sample - loss: 0.1224 - accuracy: 0.9621
# Epoch 5/5
# 60000/60000 [==============================] - 15s 244us/sample - loss: 0.1046 - accuracy: 0.9674
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.10471346569291781, 0.9664]
