# %% [markdown]
# **Question** : Load mnist dataset using inbuilt function and split into training and testing. Normalize mnist test images. Print normalized test images.

# %% [markdown]
# **Level** : Easy

# %% [markdown]
# **input format** :
#
# Dataset

# %% [markdown]
# **output format** :
#
# array

# %% [markdown]
# **Sample input** :
#
# Load the dataset using inbuilt function

# %% [markdown]
# **Sample output** : <br/>
# [[[-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5] <br/>
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5] <br/>
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5] <br/>
#   ...
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]  <br/>
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]  <br/>
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]]  <br/>

# %%
import tensorflow as tf

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_images1 = (train_images / 255) - 0.5
print(train_images1)
test_images1 = (test_images / 255) - 0.5
print(test_images1)
# Out:
# [[[-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   ...
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]]
#
#  [[-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   ...
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]]
#
#  [[-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   ...
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]]
#
#  ...
#
#  [[-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   ...
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
#   [-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]
# ...
