# %% [markdown]
# **Question**: Load, split, normalize and flatten the mnist dataset. Build, compile, train and evaluate the sequential model using loss as MeanSquaredError and optimizer as stochastic gradient descent.

# %% [markdown]
# **Description** :
#
# * Load mnist dataset using inbuilt function and split into training and testing.
# * Normalize mnist train,test images.
# * Flatten mnist train, test images.
# * Define sequential model. Add a dense layer with 64 neurons, relu activation and input shape. Add a second dense layer with 64 neurons and softmax activation. Add the last dense layer with 10 neurons and sigmoid activation.
# * Compile the model using stochastic gradient descent optimizer, loss as MeanSquaredError and accuracy as metrics.
# * Train our model using 5 epochs and 32 as batch size parameter
# * Evaluate our trained model using test images and labels.

# %% [markdown]
# **Level** : Hard

# %% [markdown]
# **input format** :
#
# Dataset

# %% [markdown]
# **output format** :
#
# Model accuracy

# %% [markdown]
# **Sample input** :
#
# Load the dataset using inbuilt function

# %% [markdown]
# **Sample output** :
#
# Accuracy : 0.80

# %%
import tensorflow as tf

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(64, activation = 'relu' , input_shape=(784, )))
model.add(tf.keras.layers.Dense(64, activation = 'softmax' ))
model.add(tf.keras.layers.Dense(10, activation = 'sigmoid' ))

model.compile('sgd', loss=tf.keras.losses.MeanSquaredError() ,metrics = ['accuracy'] )

model.fit(train_images,tf.keras.utils.to_categorical(train_labels),
  epochs=5,batch_size=32)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.2174 - accuracy: 0.0986
# Epoch 2/5
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.1700 - accuracy: 0.1020
# Epoch 3/5
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.1398 - accuracy: 0.0999
# Epoch 4/5
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.1161 - accuracy: 0.1021
# Epoch 5/5
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.1054 - accuracy: 0.0975

# %%
model.evaluate(test_images,tf.keras.utils.to_categorical(test_labels))
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
