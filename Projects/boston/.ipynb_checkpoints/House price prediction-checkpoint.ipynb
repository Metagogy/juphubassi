# %% [markdown]
# Download the dataset from below link

# %%
#https://drive.google.com/file/d/1GfvKA0qznNVknghV4botnNxyH-KvODOC/view

# %%
import pandas as pd

# %%
df = pd.read_csv('./housepricedata.csv')

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]])

# %%
X = dataset[:,0:10]

# %%
Y = dataset[:,10]

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=10,
          validation_data=(X_val, Y_val))
# Out:
# Train on 1022 samples, validate on 219 samples
# Epoch 1/10
# 1022/1022 [==============================] - 1s 1ms/step - loss: 0.6976 - accuracy: 0.4090 - val_loss: 0.6956 - val_accuracy: 0.4703
# Epoch 2/10
# 1022/1022 [==============================] - 0s 63us/step - loss: 0.6928 - accuracy: 0.5059 - val_loss: 0.6901 - val_accuracy: 0.5753
# Epoch 3/10
# 1022/1022 [==============================] - 0s 72us/step - loss: 0.6884 - accuracy: 0.5910 - val_loss: 0.6856 - val_accuracy: 0.6575
# Epoch 4/10
# 1022/1022 [==============================] - 0s 60us/step - loss: 0.6843 - accuracy: 0.6575 - val_loss: 0.6812 - val_accuracy: 0.7032
# Epoch 5/10
# 1022/1022 [==============================] - 0s 67us/step - loss: 0.6803 - accuracy: 0.7143 - val_loss: 0.6767 - val_accuracy: 0.7397
# Epoch 6/10
# 1022/1022 [==============================] - 0s 73us/step - loss: 0.6759 - accuracy: 0.7573 - val_loss: 0.6718 - val_accuracy: 0.7626
# Epoch 7/10
# 1022/1022 [==============================] - 0s 67us/step - loss: 0.6713 - accuracy: 0.7554 - val_loss: 0.6669 - val_accuracy: 0.7900
# Epoch 8/10
# 1022/1022 [==============================] - 0s 68us/step - loss: 0.6666 - accuracy: 0.7935 - val_loss: 0.6616 - val_accuracy: 0.8082
# Epoch 9/10
# 1022/1022 [==============================] - 0s 80us/step - loss: 0.6614 - accuracy: 0.7886 - val_loss: 0.6557 - val_accuracy: 0.8219
# Epoch 10/10
# 1022/1022 [==============================] - 0s 60us/step - loss: 0.6549 - accuracy: 0.8239 - val_loss: 0.6482 - val_accuracy: 0.8311

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 219/219 [==============================] - 0s 44us/step
# 0.8584474921226501

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist_2 = model_2.fit(X_train, Y_train,
          batch_size=32, epochs=10,
          validation_data=(X_val, Y_val))
# Out:
# Train on 1022 samples, validate on 219 samples
# Epoch 1/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7554 - val_loss: 0.4130 - val_accuracy: 0.8356
# Epoch 2/10
# 1022/1022 [==============================] - 1s 1ms/step - loss: 0.3712 - accuracy: 0.8454 - val_loss: 0.3025 - val_accuracy: 0.8447
# Epoch 3/10
# 1022/1022 [==============================] - 1s 1ms/step - loss: 0.3066 - accuracy: 0.8787 - val_loss: 0.3210 - val_accuracy: 0.8676
# Epoch 4/10
# 1022/1022 [==============================] - 1s 1ms/step - loss: 0.2779 - accuracy: 0.8924 - val_loss: 0.2751 - val_accuracy: 0.8904
# Epoch 5/10
# 1022/1022 [==============================] - 1s 1ms/step - loss: 0.2704 - accuracy: 0.8875 - val_loss: 0.2564 - val_accuracy: 0.8950
# Epoch 6/10
# 1022/1022 [==============================] - 1s 1ms/step - loss: 0.2774 - accuracy: 0.8982 - val_loss: 0.3371 - val_accuracy: 0.8676
# Epoch 7/10
# 1022/1022 [==============================] - 2s 1ms/step - loss: 0.2736 - accuracy: 0.8914 - val_loss: 0.2718 - val_accuracy: 0.8950
# Epoch 8/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.2508 - accuracy: 0.9022 - val_loss: 0.2445 - val_accuracy: 0.8858
# Epoch 9/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.2489 - accuracy: 0.9080 - val_loss: 0.2663 - val_accuracy: 0.8904
# Epoch 10/10
# 1022/1022 [==============================] - 1s 1ms/step - loss: 0.2286 - accuracy: 0.9012 - val_loss: 0.2590 - val_accuracy: 0.8995

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])
plt.plot(hist_2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
from keras.layers import Dropout
from keras import regularizers

# %%
model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

# %%
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist_3 = model_3.fit(X_train, Y_train,
          batch_size=32, epochs=10,
          validation_data=(X_val, Y_val))
# Out:
# Train on 1022 samples, validate on 219 samples
# Epoch 1/10
# 1022/1022 [==============================] - 3s 3ms/step - loss: 14.2434 - accuracy: 0.6595 - val_loss: 3.8766 - val_accuracy: 0.8219
# Epoch 2/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 1.6654 - accuracy: 0.8307 - val_loss: 0.6620 - val_accuracy: 0.8539
# Epoch 3/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.5643 - accuracy: 0.8611 - val_loss: 0.5067 - val_accuracy: 0.8721
# Epoch 4/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.5066 - accuracy: 0.8679 - val_loss: 0.4764 - val_accuracy: 0.8584
# Epoch 5/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.5146 - accuracy: 0.8591 - val_loss: 0.4906 - val_accuracy: 0.8630
# Epoch 6/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.4808 - accuracy: 0.8738 - val_loss: 0.4641 - val_accuracy: 0.8858
# Epoch 7/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.4767 - accuracy: 0.8728 - val_loss: 0.4524 - val_accuracy: 0.8721
# Epoch 8/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.4761 - accuracy: 0.8738 - val_loss: 0.4914 - val_accuracy: 0.8858
# Epoch 9/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.4663 - accuracy: 0.8728 - val_loss: 0.5872 - val_accuracy: 0.7763
# Epoch 10/10
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.4589 - accuracy: 0.8855 - val_loss: 0.4432 - val_accuracy: 0.8813

# %%
plt.plot(hist_3.history['loss'])
plt.plot(hist_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3.history['accuracy'])
plt.plot(hist_3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
